# %% [markdown]
# # Semi-supervised training for image classification
#
# [Dr. Diego Ortego](https://sites.google.com/view/diegoortego/)
#
# Senior Research Scientist at [NielsenIQ (NIQ)](https://nielseniq.com/global/es/)
#
# ---
#
# This lab will illustrate how to specify and train a CNN for image classification using a straigtforward [pseudo-labeling](https://arxiv.org/abs/1908.02983) for semi-supervised learning. Here, we will use the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html) (50K images with 32x32 resolution).

# %% [markdown]
# ## Instructions
#
# Anywhere you see a **???** in the code below, fill in in with the correct code.

# %%
import sys
print(sys.version)
# Out:
# 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]

# %% [markdown]
# Enable GPU acceleration
# # Enable GPU acceleration

# %% [markdown]
# # Import packages
# Find the PyTorch docs at https://pytorch.org/docs/stable/index.html
#
# Tutorials: https://pytorch.org/tutorials/

# %%
import torch
import torchvision
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.utils.data as data
from torch import optim
from torchvision import datasets, transforms
import torch.nn.functional as F

from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import random
import os
import time

# %%
print('PyTorch version:', torch.__version__)
torch.cuda.get_device_properties(0).total_memory
# Out:
# PyTorch version: 2.0.0+cu118
# 15835398144

# %%
class configuration:
  def __init__(self):
    self.experiment_name = "Regs_Mix_4K_smallNet"
    self.num_classes = 10
    self.lr = 0.1 #learning rate
    self.M = [80, 90] #Epochs to reduce learning rate x0.1
    self.batch_size = 100 #Training batch size
    self.test_batch_size = 100 #Validation batch size
    self.epoch = 100 #Number of epochs
    self.labeled_samples = 4000 #Number of labeled samples
    self.labeled_batch_size = 16 #Number of labeled samples per batch
    self.train_root = "./data" 
    self.download = True
    self.weightReg1 = 0.8 #Weight for "fair" regularization term
    self.weightReg2 = 0.4 #Weight for entropy minimization regularization term
    self.Mixup_Alpha = 1 #Mixup parameter for alpha and beta in the Beta distribution
    self.epoch_update = 1 #Number of epochs used to generate pseudo-labels
    self.seed = 271828

# %%
## Create arguments object
args = configuration()

# %%
# Make sure to enable GPU acceleration!
device = 'cuda'

# Set random seed for reproducability
torch.backends.cudnn.deterministic = True  # fix the GPU to deterministic mode
torch.manual_seed(args.seed)  # CPU seed
torch.cuda.manual_seed_all(args.seed)  # GPU seed
random.seed(args.seed)  # python seed for image transformation
np.random.seed(args.seed)

# %% [markdown]
# # Define network architecture

# %%
class SimpleCNN(nn.Module):
    
    def __init__(self, num_classes=10):
        super(SimpleCNN, self).__init__()

        self.activation = nn.LeakyReLU(0.1)
        self.conv1a = nn.Conv2d(3, 128, 3, padding=1)
        self.bn1a = nn.BatchNorm2d(128)
        self.conv1b = nn.Conv2d(128, 128, 3, padding=1)
        self.bn1b = nn.BatchNorm2d(128)
        self.mp1 = nn.MaxPool2d(2, stride=2, padding=0)
        
        self.conv2a = nn.Conv2d(128, 256, 3, padding=1)
        self.bn2a = nn.BatchNorm2d(256)
        self.conv2b = nn.Conv2d(256, 256, 3, padding=1)
        self.bn2b = nn.BatchNorm2d(256)
        self.mp2 = nn.MaxPool2d(2, stride=2, padding=0)
        
        self.conv3a = nn.Conv2d(256, 512, 3, padding=0)
        self.bn3a = nn.BatchNorm2d(512)
        self.conv3b = nn.Conv2d(512, 128, 1, padding=0)
        self.bn3b = nn.BatchNorm2d(128)
        self.ap3 = nn.AdaptiveAvgPool2d((1, 1))

        self.fc1 = nn.Linear(128, num_classes)


    def forward(self, x, debug=False):
        x = self.activation(self.bn1a(self.conv1a(x)))
        x = self.activation(self.bn1b(self.conv1b(x)))
        x = self.mp1(x)
        
        x = self.activation(self.bn2a(self.conv2a(x)))
        x = self.activation(self.bn2b(self.conv2b(x)))
        x = self.mp2(x)
        
        x = self.activation(self.bn3a(self.conv3a(x)))
        x = self.activation(self.bn3b(self.conv3b(x)))
        x = self.ap3(x)

        x = x.view(-1, 128)

        return self.fc1(x)

# %% [markdown]
# # Create a custom dataset for CIFAR-10
# PyTorch comes with a built-in dataset class for the CIFAR-10 dataset, but we need extra funcionalities for semi-supervised learning.
# PyTorch also has built-in dataset classes for other common datasets and tasks like ImageNet. See: https://pytorch.org/docs/stable/torchvision/datasets.html

# %%
class Cifar10Train(torchvision.datasets.CIFAR10):
    # Init method
    def __init__(self, args, train=True, transform=None, target_transform=None, download=False):
        super(Cifar10Train, self).__init__(args.train_root, train=train, transform=transform, target_transform=target_transform, download=download)
        self.args = args

        self.targets = np.asarray(self.targets)
        self.soft_labels = np.zeros((len(self.targets), 10), dtype=np.float32)
        self.prediction = np.zeros((self.args.epoch_update, len(self.data), 10), dtype=np.float32)
        self._num = int(len(self.targets) - int(args.labeled_samples))
        self.original_labels = np.copy(self.targets)
 
    ##Create Labeled/unlabeled splits
    def generate_SemiSup_data(self):
        np.random.seed(self.args.seed)

        original_labels = np.copy(self.targets)
        unlab_indexes = [] # initialize the vector
        lab_indexes = []


        num_unlab_samples = self._num
        num_clean_samples = len(self.targets) - num_unlab_samples

        lab_per_class = int(num_clean_samples / self.args.num_classes)
        unlab_per_class = int(num_unlab_samples / self.args.num_classes)

        for id in range(self.args.num_classes):
            indexes = np.where(original_labels == id)[0]
            np.random.shuffle(indexes)

            for i in range(len(indexes)):
                if i < unlab_per_class: ##Labels for unlabeled samples are randomly defined
                    label_sym = np.random.randint(self.args.num_classes, dtype=np.int32)
                    self.targets[indexes[i]] = label_sym

                self.soft_labels[indexes[i]][self.targets[indexes[i]]] = 1

            unlab_indexes.extend(indexes[:unlab_per_class])
            lab_indexes.extend(indexes[unlab_per_class:])

        return original_labels, self.targets,  np.asarray(unlab_indexes),  np.asarray(lab_indexes)

    def update_pseudoLabels(self, result, unlabeled_idx):

        nb_unlab = len(unlabeled_idx) #Amount of unlabeled to relabel
        self.soft_labels[unlabeled_idx] = result[unlabeled_idx]
        self.targets[unlabeled_idx] = self.soft_labels[unlabeled_idx].argmax(axis=1).astype(np.int64)

        print("Samples relabeled with the prediction: ", str(len(unlabeled_idx)))

    def __getitem__(self, index): 
        img, labels, soft_labels = self.data[index], self.targets[index], self.soft_labels[index]
        
        img = Image.fromarray(img)
        
        if self.transform is not None:
            img = self.transform(img)
            
        if self.target_transform is not None:
            labels = self.target_transform(labels)

        return img, labels, soft_labels, index

# %% [markdown]
# # Pseudo-Labeling training function
# Write the training loss for [Pseudo-labeling](https://arxiv.org/abs/1908.02983). In particular implement, Eq. 2, Eq. 3 and Eq. 7.

# %%
def train_CrossEntropy_partialRelab(args, model, device, train_loader, optimizer, epoch, train_unlabeled_indexes):

    train_loss = []
    acc_per_batch = []

    # switch to train mode
    model.train()

    results = np.zeros((len(train_loader.dataset), args.num_classes), dtype=np.float32)

    alpha = args.Mixup_Alpha

    counter = 1
    correct = 0
    for batch_idx, (imgs, labels, soft_labels, index) in enumerate(train_loader):
        
        ##### To fill: move tensors from CPU to GPU.
        images = imgs.to(device)
        labels = labels.to(device)
        soft_labels = soft_labels.to(device) 
        
        batch_size = images.size()[0]

        ########################### Mixup ######################################
        ## Extra forward pass to get non-mixed predictions that are needed for labels
        optimizer.zero_grad()
        output_x1 = model(images)
        output_x1.detach_()
        optimizer.zero_grad()

        if alpha > 0:
          lam = np.random.beta(alpha, alpha)
        else:
          lam = 1

        index_mix = torch.randperm(batch_size).cuda()

        ##### To fill: replace ??? by the right variable. This is the mixup formula for the input data. 
        imagesMix = lam * images + (1-lam) * images[index_mix, :]

        ##Get mixup labels needed for the loss
        soft_labels_a, soft_labels_b = soft_labels, soft_labels[index_mix]
        outputs = model(imagesMix) ##Logits
        ########################################################################

        prob = F.softmax(outputs, dim=1)
        prob_avg = torch.mean(prob, dim=0)
        p = torch.ones(args.num_classes).to(device) / args.num_classes
       
        # Fair classification regularizer (equivalent to Eq. 2)
        L_p = -torch.sum(torch.log(prob_avg) * p)
        
        # Entropy minimization regularizer (Eq. 3)
        ##### To fill: complete the entropy minimization regularization
        L_e = -torch.mean(torch.sum(F.softmax(outputs) * F.log_softmax(outputs, dim=1), dim=1))
 
        ## Cross-entropy loss with soft labels (Eq. 7)
        ##### To fill: implement cross-entropy with soft-labels for each image used for mixing
        mixup_loss_a = -torch.mean(torch.sum(soft_labels_a * F.log_softmax(outputs, dim=1), dim=1))
        mixup_loss_b = -torch.mean(torch.sum(soft_labels_b * F.log_softmax(outputs, dim=1), dim=1))
        
        L_c = lam * mixup_loss_a + (1 - lam) * mixup_loss_b
        outputs = output_x1
        prob = F.softmax(outputs, dim=1)

        ##Final loss = Cross-entropy with mixup + regularizations
        loss = L_c + args.weightReg1 * L_p + args.weightReg2 * L_e
         
        ##Save network preditions. Will be used to modify the soft pseudo-labels of the dataset
        results[index.detach().numpy().tolist()] = prob.cpu().detach().numpy().tolist()

        train_loss.append(loss.item())

        preds = outputs.max(1, keepdim=True)[1]  # get the index of the max log-probability
        correct += preds.eq(labels.view_as(preds)).sum().item()
        if images.size(0) < args.batch_size:
          acc_per_batch.append(100. * correct / (batch_idx*args.batch_size + images.size(0)))
        else:
          acc_per_batch.append(100. * correct / ((batch_idx + 1) * args.batch_size))
        

        # Empty gradient buffer (if not done, gradients are accumulated)
        optimizer.zero_grad()
        
        ##### To fill: perform backward pass
        loss.backward()
        
        ##### To fill: perform gradient descend step
        optimizer.step()

        if counter % 15 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}, Accuracy: {:.0f}%, Learning rate: {:.6f}'.format(
                epoch, counter * len(images), len(train_loader.dataset),
                       100. * counter / len(train_loader), loss.item(),
                       acc_per_batch[-1], optimizer.param_groups[0]['lr']))
        counter = counter + 1

    # update soft labels
    train_loader.dataset.update_pseudoLabels(results, train_unlabeled_indexes)
    
    return sum(train_loss)/len(train_loss), acc_per_batch[-1]

# %% [markdown]
# # Testing function

# %%
def testing(args, model, device, test_loader):
    model.eval()
    loss_per_batch = []
    acc_val_per_batch =[]
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(test_loader):
            data, target = data.to(device), target.to(device)
            output = model(data)
            ##Here cross-entropy loss is also estimated, but is split into two parts; log_softmax + negative log likelihood loss
            output = F.log_softmax(output, dim=1)
            test_loss += F.nll_loss(output, target, reduction='mean').item()
            loss_per_batch.append(F.nll_loss(output, target).item())
            pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            acc_val_per_batch.append(100. * correct / ((batch_idx+1)*args.test_batch_size))

    test_loss /= len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

    loss_per_epoch = [np.average(loss_per_batch)]
    acc_val_per_epoch = [np.array(100. * correct / len(test_loader.dataset))]

    return (loss_per_epoch, acc_val_per_epoch)

# %% [markdown]
# # Data Transformations
# We need to specify a transform here to convert images to torch tensors.
#
# I'm adding a normalization transform here too so that the images have mean zero and unit variance. This is optional. For some problems (models/datasets) proper normalization is important for performance. For others (e.g. models with batch normalization early on), the importance of normalization is less.

# %%
mean = [0.4914, 0.4822, 0.4465]
std = [0.2023, 0.1994, 0.2010]

## Transformations for training data
transform_train = transforms.Compose([
    transforms.Pad(2, padding_mode='reflect'),
    transforms.RandomCrop(32),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

## Transformations for test data
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

# %%
# Create dataset
cifar10_train_val = torchvision.datasets.CIFAR10(args.train_root, train=True, download=True)

trainset = Cifar10Train(args, train=True, transform=transform_train)
##Generate the semi-supervised data: Labels for unlabeled samples are initialized randomly (not the best, but works)
labeled_labels, unlabeled_labels, train_unlabeled_indexes, train_labeled_indexes = trainset.generate_SemiSup_data()

# Create dataLoaders
train_loader = torch.utils.data.DataLoader(trainset, batch_size=args.batch_size, shuffle=True, num_workers=8, pin_memory=True)
testset = datasets.CIFAR10(root='./data', train=False, download=False, transform=transform_test)
test_loader = torch.utils.data.DataLoader(testset, batch_size=args.test_batch_size, shuffle=False, num_workers=8, pin_memory=True)

print('-------> Data loading')
print("Training with {0} labeled samples ({1} unlabeled samples)".format(len(labeled_labels)-len(train_unlabeled_indexes), len(train_unlabeled_indexes)))

##Create the CNN
model = SimpleCNN(num_classes = 10).to(device)

print('Total params: %2.fM' % (sum(p.numel() for p in model.parameters()) / 1000000.0))

milestones = args.M


##Define optimizer
optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=0.9, weight_decay=1e-4)
##Define scheduler
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=milestones, gamma=0.1)
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# -------> Data loading
# Training with 4000 labeled samples (46000 unlabeled samples)
# Total params:  2M

# %%
loss_train_epoch = []
loss_test_epoch = []
acc_train_per_epoch = []
acc_test_per_epoch = []
new_labels = []

cont = 0

res_path = "./metrics_" + args.experiment_name

if not os.path.isdir(res_path):
    os.makedirs(res_path)

for epoch in range(1, args.epoch + 1):

    # One epoch of training
    st = time.time()
    scheduler.step()

    print("SSL with " + str(args.labeled_samples) + " labeled samples, epoch " + str(epoch))

    loss_per_epoch, top1_train_ac = train_CrossEntropy_partialRelab(args, model, device, train_loader, optimizer, epoch, train_unlabeled_indexes)
    loss_train_epoch += [loss_per_epoch]

    # test
    loss_per_epoch_test, acc_val_per_epoch_i = testing(args, model, device, test_loader)

    loss_test_epoch += loss_per_epoch_test
    acc_train_per_epoch += [top1_train_ac]
    acc_test_per_epoch += acc_val_per_epoch_i


    if epoch == 1:
        best_acc_val = acc_val_per_epoch_i[-1]
        
    else:
        if acc_val_per_epoch_i[-1] > best_acc_val:
            best_acc_val = acc_val_per_epoch_i[-1]


    ##Save model in a given epoch (last epoch by default)
    # if epoch==args.epoch:
    #     torch.save(model.state_dict(), "mySSLmodel")

    np.save(res_path + '/' + 'LOSS_epoch_train.npy', np.asarray(loss_train_epoch))
    np.save(res_path + '/' + 'LOSS_epoch_val.npy', np.asarray(loss_test_epoch))

    # save accuracies:
    np.save(res_path + '/' + 'accuracy_per_epoch_train.npy', np.asarray(acc_train_per_epoch))
    np.save(res_path + '/' + 'accuracy_per_epoch_val.npy', np.asarray(acc_test_per_epoch))

    cont += 1
# Out:
# SSL with 4000 labeled samples, epoch 1
# /usr/local/lib/python3.9/dist-packages/torch/optim/lr_scheduler.py:139: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# <ipython-input-9-765fdfdc5e68>:55: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   L_e = -torch.mean(torch.sum(F.softmax(outputs) * F.log_softmax(outputs, dim=1), dim=1))
# Train Epoch: 1 [1500/50000 (3%)]	Loss: 5.126019, Accuracy: 11%, Learning rate: 0.100000
# Train Epoch: 1 [3000/50000 (6%)]	Loss: 5.081776, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [4500/50000 (9%)]	Loss: 5.164018, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [6000/50000 (12%)]	Loss: 5.081333, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [7500/50000 (15%)]	Loss: 5.089859, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [9000/50000 (18%)]	Loss: 5.081481, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [10500/50000 (21%)]	Loss: 5.042976, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [12000/50000 (24%)]	Loss: 5.087147, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [13500/50000 (27%)]	Loss: 5.096838, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 5.063117, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [16500/50000 (33%)]	Loss: 5.060439, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [18000/50000 (36%)]	Loss: 5.057928, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [19500/50000 (39%)]	Loss: 5.063114, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [21000/50000 (42%)]	Loss: 5.072723, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [22500/50000 (45%)]	Loss: 5.056800, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [24000/50000 (48%)]	Loss: 5.084250, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [25500/50000 (51%)]	Loss: 5.076694, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [27000/50000 (54%)]	Loss: 5.060188, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [28500/50000 (57%)]	Loss: 5.052640, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 5.064291, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [31500/50000 (63%)]	Loss: 5.061011, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [33000/50000 (66%)]	Loss: 5.065403, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [34500/50000 (69%)]	Loss: 5.068956, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [36000/50000 (72%)]	Loss: 5.049037, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [37500/50000 (75%)]	Loss: 5.060294, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [39000/50000 (78%)]	Loss: 5.077241, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [40500/50000 (81%)]	Loss: 5.077220, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [42000/50000 (84%)]	Loss: 5.062768, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [43500/50000 (87%)]	Loss: 5.049340, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 5.087962, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [46500/50000 (93%)]	Loss: 5.087654, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [48000/50000 (96%)]	Loss: 5.075304, Accuracy: 10%, Learning rate: 0.100000
# Train Epoch: 1 [49500/50000 (99%)]	Loss: 5.064972, Accuracy: 10%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0222, Accuracy: 2161/10000 (22%)
#
# SSL with 4000 labeled samples, epoch 2
# Train Epoch: 2 [1500/50000 (3%)]	Loss: 5.062009, Accuracy: 22%, Learning rate: 0.100000
# Train Epoch: 2 [3000/50000 (6%)]	Loss: 5.052542, Accuracy: 22%, Learning rate: 0.100000
# Train Epoch: 2 [4500/50000 (9%)]	Loss: 5.056777, Accuracy: 21%, Learning rate: 0.100000
# Train Epoch: 2 [6000/50000 (12%)]	Loss: 5.056438, Accuracy: 21%, Learning rate: 0.100000
# Train Epoch: 2 [7500/50000 (15%)]	Loss: 5.051928, Accuracy: 22%, Learning rate: 0.100000
# Train Epoch: 2 [9000/50000 (18%)]	Loss: 5.060275, Accuracy: 22%, Learning rate: 0.100000
# Train Epoch: 2 [10500/50000 (21%)]	Loss: 5.062621, Accuracy: 22%, Learning rate: 0.100000
# Train Epoch: 2 [12000/50000 (24%)]	Loss: 5.058666, Accuracy: 22%, Learning rate: 0.100000
# Train Epoch: 2 [13500/50000 (27%)]	Loss: 5.052257, Accuracy: 22%, Learning rate: 0.100000
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 5.061053, Accuracy: 22%, Learning rate: 0.100000
# Train Epoch: 2 [16500/50000 (33%)]	Loss: 5.052856, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [18000/50000 (36%)]	Loss: 5.051193, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [19500/50000 (39%)]	Loss: 5.054544, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [21000/50000 (42%)]	Loss: 5.059120, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [22500/50000 (45%)]	Loss: 5.051191, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [24000/50000 (48%)]	Loss: 5.060609, Accuracy: 22%, Learning rate: 0.100000
# Train Epoch: 2 [25500/50000 (51%)]	Loss: 5.049675, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [27000/50000 (54%)]	Loss: 5.048611, Accuracy: 22%, Learning rate: 0.100000
# Train Epoch: 2 [28500/50000 (57%)]	Loss: 5.056897, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 5.049558, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [31500/50000 (63%)]	Loss: 5.059827, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [33000/50000 (66%)]	Loss: 5.060693, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [34500/50000 (69%)]	Loss: 5.066782, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [36000/50000 (72%)]	Loss: 5.049984, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [37500/50000 (75%)]	Loss: 5.037842, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [39000/50000 (78%)]	Loss: 5.062146, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [40500/50000 (81%)]	Loss: 5.064533, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [42000/50000 (84%)]	Loss: 5.056484, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [43500/50000 (87%)]	Loss: 5.054888, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [45000/50000 (90%)]	Loss: 5.059093, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [46500/50000 (93%)]	Loss: 5.053140, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [48000/50000 (96%)]	Loss: 5.064116, Accuracy: 23%, Learning rate: 0.100000
# Train Epoch: 2 [49500/50000 (99%)]	Loss: 5.038581, Accuracy: 23%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0213, Accuracy: 3257/10000 (33%)
#
# SSL with 4000 labeled samples, epoch 3
# Train Epoch: 3 [1500/50000 (3%)]	Loss: 5.044810, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [3000/50000 (6%)]	Loss: 5.046731, Accuracy: 53%, Learning rate: 0.100000
# Train Epoch: 3 [4500/50000 (9%)]	Loss: 5.046432, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [6000/50000 (12%)]	Loss: 5.041754, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [7500/50000 (15%)]	Loss: 5.045035, Accuracy: 53%, Learning rate: 0.100000
# Train Epoch: 3 [9000/50000 (18%)]	Loss: 5.056991, Accuracy: 53%, Learning rate: 0.100000
# Train Epoch: 3 [10500/50000 (21%)]	Loss: 5.046545, Accuracy: 53%, Learning rate: 0.100000
# Train Epoch: 3 [12000/50000 (24%)]	Loss: 5.039072, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [13500/50000 (27%)]	Loss: 5.041369, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [15000/50000 (30%)]	Loss: 5.048354, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [16500/50000 (33%)]	Loss: 5.059672, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [18000/50000 (36%)]	Loss: 5.009314, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [19500/50000 (39%)]	Loss: 5.038566, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [21000/50000 (42%)]	Loss: 5.029982, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [22500/50000 (45%)]	Loss: 5.041001, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [24000/50000 (48%)]	Loss: 5.046826, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [25500/50000 (51%)]	Loss: 5.050176, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [27000/50000 (54%)]	Loss: 5.038014, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [28500/50000 (57%)]	Loss: 5.045203, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [30000/50000 (60%)]	Loss: 5.051445, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [31500/50000 (63%)]	Loss: 5.037934, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [33000/50000 (66%)]	Loss: 5.022792, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [34500/50000 (69%)]	Loss: 5.046467, Accuracy: 52%, Learning rate: 0.100000
# Train Epoch: 3 [36000/50000 (72%)]	Loss: 5.033425, Accuracy: 51%, Learning rate: 0.100000
# Train Epoch: 3 [37500/50000 (75%)]	Loss: 5.035721, Accuracy: 51%, Learning rate: 0.100000
# Train Epoch: 3 [39000/50000 (78%)]	Loss: 5.028550, Accuracy: 51%, Learning rate: 0.100000
# Train Epoch: 3 [40500/50000 (81%)]	Loss: 5.033401, Accuracy: 51%, Learning rate: 0.100000
# Train Epoch: 3 [42000/50000 (84%)]	Loss: 5.026621, Accuracy: 51%, Learning rate: 0.100000
# Train Epoch: 3 [43500/50000 (87%)]	Loss: 5.040410, Accuracy: 51%, Learning rate: 0.100000
# Train Epoch: 3 [45000/50000 (90%)]	Loss: 5.041708, Accuracy: 51%, Learning rate: 0.100000
# Train Epoch: 3 [46500/50000 (93%)]	Loss: 5.034902, Accuracy: 51%, Learning rate: 0.100000
# Train Epoch: 3 [48000/50000 (96%)]	Loss: 5.051751, Accuracy: 51%, Learning rate: 0.100000
# Train Epoch: 3 [49500/50000 (99%)]	Loss: 5.050026, Accuracy: 51%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0202, Accuracy: 3605/10000 (36%)
#
# SSL with 4000 labeled samples, epoch 4
# Train Epoch: 4 [1500/50000 (3%)]	Loss: 4.998787, Accuracy: 64%, Learning rate: 0.100000
# Train Epoch: 4 [3000/50000 (6%)]	Loss: 4.999793, Accuracy: 64%, Learning rate: 0.100000
# Train Epoch: 4 [4500/50000 (9%)]	Loss: 4.994918, Accuracy: 63%, Learning rate: 0.100000
# Train Epoch: 4 [6000/50000 (12%)]	Loss: 5.022288, Accuracy: 63%, Learning rate: 0.100000
# Train Epoch: 4 [7500/50000 (15%)]	Loss: 5.040242, Accuracy: 63%, Learning rate: 0.100000
# Train Epoch: 4 [9000/50000 (18%)]	Loss: 4.984207, Accuracy: 62%, Learning rate: 0.100000
# Train Epoch: 4 [10500/50000 (21%)]	Loss: 5.019248, Accuracy: 62%, Learning rate: 0.100000
# Train Epoch: 4 [12000/50000 (24%)]	Loss: 4.988940, Accuracy: 62%, Learning rate: 0.100000
# Train Epoch: 4 [13500/50000 (27%)]	Loss: 4.986171, Accuracy: 62%, Learning rate: 0.100000
# Train Epoch: 4 [15000/50000 (30%)]	Loss: 5.020977, Accuracy: 62%, Learning rate: 0.100000
# Train Epoch: 4 [16500/50000 (33%)]	Loss: 4.965499, Accuracy: 62%, Learning rate: 0.100000
# Train Epoch: 4 [18000/50000 (36%)]	Loss: 5.009991, Accuracy: 62%, Learning rate: 0.100000
# Train Epoch: 4 [19500/50000 (39%)]	Loss: 5.032141, Accuracy: 62%, Learning rate: 0.100000
# Train Epoch: 4 [21000/50000 (42%)]	Loss: 5.028933, Accuracy: 62%, Learning rate: 0.100000
# Train Epoch: 4 [22500/50000 (45%)]	Loss: 4.952897, Accuracy: 62%, Learning rate: 0.100000
# Train Epoch: 4 [24000/50000 (48%)]	Loss: 5.016593, Accuracy: 62%, Learning rate: 0.100000
# Train Epoch: 4 [25500/50000 (51%)]	Loss: 5.012373, Accuracy: 62%, Learning rate: 0.100000
# Train Epoch: 4 [27000/50000 (54%)]	Loss: 5.027438, Accuracy: 62%, Learning rate: 0.100000
# Train Epoch: 4 [28500/50000 (57%)]	Loss: 5.032293, Accuracy: 61%, Learning rate: 0.100000
# Train Epoch: 4 [30000/50000 (60%)]	Loss: 5.024314, Accuracy: 61%, Learning rate: 0.100000
# Train Epoch: 4 [31500/50000 (63%)]	Loss: 4.992931, Accuracy: 61%, Learning rate: 0.100000
# Train Epoch: 4 [33000/50000 (66%)]	Loss: 5.011450, Accuracy: 61%, Learning rate: 0.100000
# Train Epoch: 4 [34500/50000 (69%)]	Loss: 5.021345, Accuracy: 61%, Learning rate: 0.100000
# Train Epoch: 4 [36000/50000 (72%)]	Loss: 5.006806, Accuracy: 61%, Learning rate: 0.100000
# Train Epoch: 4 [37500/50000 (75%)]	Loss: 5.028255, Accuracy: 61%, Learning rate: 0.100000
# Train Epoch: 4 [39000/50000 (78%)]	Loss: 5.033405, Accuracy: 61%, Learning rate: 0.100000
# Train Epoch: 4 [40500/50000 (81%)]	Loss: 5.011924, Accuracy: 61%, Learning rate: 0.100000
# Train Epoch: 4 [42000/50000 (84%)]	Loss: 4.991286, Accuracy: 61%, Learning rate: 0.100000
# Train Epoch: 4 [43500/50000 (87%)]	Loss: 5.009071, Accuracy: 61%, Learning rate: 0.100000
# Train Epoch: 4 [45000/50000 (90%)]	Loss: 5.023884, Accuracy: 61%, Learning rate: 0.100000
# Train Epoch: 4 [46500/50000 (93%)]	Loss: 5.034014, Accuracy: 61%, Learning rate: 0.100000
# Train Epoch: 4 [48000/50000 (96%)]	Loss: 5.010660, Accuracy: 61%, Learning rate: 0.100000
# Train Epoch: 4 [49500/50000 (99%)]	Loss: 5.004106, Accuracy: 61%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0187, Accuracy: 3805/10000 (38%)
#
# SSL with 4000 labeled samples, epoch 5
# Train Epoch: 5 [1500/50000 (3%)]	Loss: 4.927505, Accuracy: 67%, Learning rate: 0.100000
# Train Epoch: 5 [3000/50000 (6%)]	Loss: 4.968045, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [4500/50000 (9%)]	Loss: 4.929100, Accuracy: 67%, Learning rate: 0.100000
# Train Epoch: 5 [6000/50000 (12%)]	Loss: 4.965759, Accuracy: 67%, Learning rate: 0.100000
# Train Epoch: 5 [7500/50000 (15%)]	Loss: 4.962200, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [9000/50000 (18%)]	Loss: 4.967718, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [10500/50000 (21%)]	Loss: 4.950013, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [12000/50000 (24%)]	Loss: 4.919071, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [13500/50000 (27%)]	Loss: 4.899581, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [15000/50000 (30%)]	Loss: 4.929631, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [16500/50000 (33%)]	Loss: 4.895616, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [18000/50000 (36%)]	Loss: 4.876368, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [19500/50000 (39%)]	Loss: 4.968228, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [21000/50000 (42%)]	Loss: 4.929879, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [22500/50000 (45%)]	Loss: 4.945158, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [24000/50000 (48%)]	Loss: 4.905267, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [25500/50000 (51%)]	Loss: 4.974489, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [27000/50000 (54%)]	Loss: 4.975569, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [28500/50000 (57%)]	Loss: 4.957069, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [30000/50000 (60%)]	Loss: 4.962634, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [31500/50000 (63%)]	Loss: 4.936518, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [33000/50000 (66%)]	Loss: 4.942506, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [34500/50000 (69%)]	Loss: 4.933644, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [36000/50000 (72%)]	Loss: 4.943703, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [37500/50000 (75%)]	Loss: 4.957400, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [39000/50000 (78%)]	Loss: 4.947983, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [40500/50000 (81%)]	Loss: 4.907525, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [42000/50000 (84%)]	Loss: 4.923134, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [43500/50000 (87%)]	Loss: 4.938762, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [45000/50000 (90%)]	Loss: 4.900824, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [46500/50000 (93%)]	Loss: 4.966252, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [48000/50000 (96%)]	Loss: 4.927301, Accuracy: 66%, Learning rate: 0.100000
# Train Epoch: 5 [49500/50000 (99%)]	Loss: 4.881831, Accuracy: 66%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0173, Accuracy: 4358/10000 (44%)
#
# SSL with 4000 labeled samples, epoch 6
# Train Epoch: 6 [1500/50000 (3%)]	Loss: 4.861448, Accuracy: 70%, Learning rate: 0.100000
# Train Epoch: 6 [3000/50000 (6%)]	Loss: 4.732529, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [4500/50000 (9%)]	Loss: 4.814593, Accuracy: 70%, Learning rate: 0.100000
# Train Epoch: 6 [6000/50000 (12%)]	Loss: 4.800673, Accuracy: 70%, Learning rate: 0.100000
# Train Epoch: 6 [7500/50000 (15%)]	Loss: 4.747234, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [9000/50000 (18%)]	Loss: 4.795814, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [10500/50000 (21%)]	Loss: 4.789520, Accuracy: 70%, Learning rate: 0.100000
# Train Epoch: 6 [12000/50000 (24%)]	Loss: 4.739552, Accuracy: 70%, Learning rate: 0.100000
# Train Epoch: 6 [13500/50000 (27%)]	Loss: 4.841330, Accuracy: 70%, Learning rate: 0.100000
# Train Epoch: 6 [15000/50000 (30%)]	Loss: 4.904079, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [16500/50000 (33%)]	Loss: 4.895567, Accuracy: 70%, Learning rate: 0.100000
# Train Epoch: 6 [18000/50000 (36%)]	Loss: 4.830440, Accuracy: 70%, Learning rate: 0.100000
# Train Epoch: 6 [19500/50000 (39%)]	Loss: 4.875255, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [21000/50000 (42%)]	Loss: 4.845203, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [22500/50000 (45%)]	Loss: 4.765150, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [24000/50000 (48%)]	Loss: 4.855754, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [25500/50000 (51%)]	Loss: 4.800378, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [27000/50000 (54%)]	Loss: 4.918169, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [28500/50000 (57%)]	Loss: 4.833127, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [30000/50000 (60%)]	Loss: 4.899141, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [31500/50000 (63%)]	Loss: 4.739076, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [33000/50000 (66%)]	Loss: 4.844405, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [34500/50000 (69%)]	Loss: 4.794593, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [36000/50000 (72%)]	Loss: 4.917329, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [37500/50000 (75%)]	Loss: 4.711014, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [39000/50000 (78%)]	Loss: 4.772910, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [40500/50000 (81%)]	Loss: 4.861974, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [42000/50000 (84%)]	Loss: 4.908941, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [43500/50000 (87%)]	Loss: 4.865338, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [45000/50000 (90%)]	Loss: 4.633519, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [46500/50000 (93%)]	Loss: 4.859797, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [48000/50000 (96%)]	Loss: 4.888710, Accuracy: 69%, Learning rate: 0.100000
# Train Epoch: 6 [49500/50000 (99%)]	Loss: 4.884428, Accuracy: 69%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0159, Accuracy: 4454/10000 (45%)
#
# SSL with 4000 labeled samples, epoch 7
# Train Epoch: 7 [1500/50000 (3%)]	Loss: 4.802946, Accuracy: 72%, Learning rate: 0.100000
# Train Epoch: 7 [3000/50000 (6%)]	Loss: 4.662676, Accuracy: 70%, Learning rate: 0.100000
# Train Epoch: 7 [4500/50000 (9%)]	Loss: 4.656721, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [6000/50000 (12%)]	Loss: 4.843924, Accuracy: 72%, Learning rate: 0.100000
# Train Epoch: 7 [7500/50000 (15%)]	Loss: 4.806251, Accuracy: 72%, Learning rate: 0.100000
# Train Epoch: 7 [9000/50000 (18%)]	Loss: 4.715688, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [10500/50000 (21%)]	Loss: 4.630133, Accuracy: 72%, Learning rate: 0.100000
# Train Epoch: 7 [12000/50000 (24%)]	Loss: 4.782055, Accuracy: 72%, Learning rate: 0.100000
# Train Epoch: 7 [13500/50000 (27%)]	Loss: 4.629463, Accuracy: 72%, Learning rate: 0.100000
# Train Epoch: 7 [15000/50000 (30%)]	Loss: 4.575380, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [16500/50000 (33%)]	Loss: 4.811253, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [18000/50000 (36%)]	Loss: 4.777256, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [19500/50000 (39%)]	Loss: 4.658190, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [21000/50000 (42%)]	Loss: 4.838839, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [22500/50000 (45%)]	Loss: 4.502781, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [24000/50000 (48%)]	Loss: 4.800869, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [25500/50000 (51%)]	Loss: 4.810321, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [27000/50000 (54%)]	Loss: 4.704716, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [28500/50000 (57%)]	Loss: 4.765769, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [30000/50000 (60%)]	Loss: 4.686167, Accuracy: 72%, Learning rate: 0.100000
# Train Epoch: 7 [31500/50000 (63%)]	Loss: 4.812037, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [33000/50000 (66%)]	Loss: 4.652904, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [34500/50000 (69%)]	Loss: 4.731816, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [36000/50000 (72%)]	Loss: 4.667688, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [37500/50000 (75%)]	Loss: 4.826195, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [39000/50000 (78%)]	Loss: 4.759063, Accuracy: 72%, Learning rate: 0.100000
# Train Epoch: 7 [40500/50000 (81%)]	Loss: 4.764975, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [42000/50000 (84%)]	Loss: 4.653862, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [43500/50000 (87%)]	Loss: 4.595349, Accuracy: 71%, Learning rate: 0.100000
# Train Epoch: 7 [45000/50000 (90%)]	Loss: 4.672339, Accuracy: 72%, Learning rate: 0.100000
# Train Epoch: 7 [46500/50000 (93%)]	Loss: 4.889719, Accuracy: 72%, Learning rate: 0.100000
# Train Epoch: 7 [48000/50000 (96%)]	Loss: 4.802904, Accuracy: 72%, Learning rate: 0.100000
# Train Epoch: 7 [49500/50000 (99%)]	Loss: 4.677594, Accuracy: 72%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0150, Accuracy: 4805/10000 (48%)
#
# SSL with 4000 labeled samples, epoch 8
# Train Epoch: 8 [1500/50000 (3%)]	Loss: 4.628567, Accuracy: 76%, Learning rate: 0.100000
# Train Epoch: 8 [3000/50000 (6%)]	Loss: 4.343220, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 8 [4500/50000 (9%)]	Loss: 4.532568, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 8 [6000/50000 (12%)]	Loss: 4.424273, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 8 [7500/50000 (15%)]	Loss: 4.717581, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [9000/50000 (18%)]	Loss: 4.417377, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [10500/50000 (21%)]	Loss: 4.483033, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [12000/50000 (24%)]	Loss: 4.679314, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [13500/50000 (27%)]	Loss: 4.522994, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 8 [15000/50000 (30%)]	Loss: 4.462133, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [16500/50000 (33%)]	Loss: 4.739670, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [18000/50000 (36%)]	Loss: 4.676417, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [19500/50000 (39%)]	Loss: 4.566679, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [21000/50000 (42%)]	Loss: 4.707727, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [22500/50000 (45%)]	Loss: 4.466616, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [24000/50000 (48%)]	Loss: 4.591771, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [25500/50000 (51%)]	Loss: 4.662218, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [27000/50000 (54%)]	Loss: 4.723563, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [28500/50000 (57%)]	Loss: 4.482924, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [30000/50000 (60%)]	Loss: 4.572891, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [31500/50000 (63%)]	Loss: 4.447533, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [33000/50000 (66%)]	Loss: 4.541869, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [34500/50000 (69%)]	Loss: 4.733301, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [36000/50000 (72%)]	Loss: 4.360396, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [37500/50000 (75%)]	Loss: 4.653396, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [39000/50000 (78%)]	Loss: 4.443077, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [40500/50000 (81%)]	Loss: 4.395963, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [42000/50000 (84%)]	Loss: 4.401517, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [43500/50000 (87%)]	Loss: 4.431717, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [45000/50000 (90%)]	Loss: 4.726742, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [46500/50000 (93%)]	Loss: 4.384830, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [48000/50000 (96%)]	Loss: 4.615504, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 8 [49500/50000 (99%)]	Loss: 4.661068, Accuracy: 74%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0141, Accuracy: 5020/10000 (50%)
#
# SSL with 4000 labeled samples, epoch 9
# Train Epoch: 9 [1500/50000 (3%)]	Loss: 4.623023, Accuracy: 74%, Learning rate: 0.100000
# Train Epoch: 9 [3000/50000 (6%)]	Loss: 4.281411, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [4500/50000 (9%)]	Loss: 4.296406, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [6000/50000 (12%)]	Loss: 4.418497, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [7500/50000 (15%)]	Loss: 4.310115, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [9000/50000 (18%)]	Loss: 4.626076, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [10500/50000 (21%)]	Loss: 4.603082, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [12000/50000 (24%)]	Loss: 4.421035, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [13500/50000 (27%)]	Loss: 4.657577, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [15000/50000 (30%)]	Loss: 4.433898, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [16500/50000 (33%)]	Loss: 4.542965, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [18000/50000 (36%)]	Loss: 4.338736, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [19500/50000 (39%)]	Loss: 4.416809, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [21000/50000 (42%)]	Loss: 4.496024, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [22500/50000 (45%)]	Loss: 4.392715, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [24000/50000 (48%)]	Loss: 4.280727, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [25500/50000 (51%)]	Loss: 4.536558, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [27000/50000 (54%)]	Loss: 4.491072, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [28500/50000 (57%)]	Loss: 4.442523, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [30000/50000 (60%)]	Loss: 4.363657, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [31500/50000 (63%)]	Loss: 4.362077, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [33000/50000 (66%)]	Loss: 4.291649, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [34500/50000 (69%)]	Loss: 4.455054, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [36000/50000 (72%)]	Loss: 4.525242, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [37500/50000 (75%)]	Loss: 4.105046, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [39000/50000 (78%)]	Loss: 4.541432, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [40500/50000 (81%)]	Loss: 4.699306, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [42000/50000 (84%)]	Loss: 4.367200, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [43500/50000 (87%)]	Loss: 4.326440, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [45000/50000 (90%)]	Loss: 4.239025, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [46500/50000 (93%)]	Loss: 4.544261, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [48000/50000 (96%)]	Loss: 4.578278, Accuracy: 75%, Learning rate: 0.100000
# Train Epoch: 9 [49500/50000 (99%)]	Loss: 4.592621, Accuracy: 75%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0144, Accuracy: 4961/10000 (50%)
#
# SSL with 4000 labeled samples, epoch 10
# Train Epoch: 10 [1500/50000 (3%)]	Loss: 4.105700, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [3000/50000 (6%)]	Loss: 4.481832, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [4500/50000 (9%)]	Loss: 4.496582, Accuracy: 76%, Learning rate: 0.100000
# Train Epoch: 10 [6000/50000 (12%)]	Loss: 4.358163, Accuracy: 76%, Learning rate: 0.100000
# Train Epoch: 10 [7500/50000 (15%)]	Loss: 4.061101, Accuracy: 76%, Learning rate: 0.100000
# Train Epoch: 10 [9000/50000 (18%)]	Loss: 4.442225, Accuracy: 76%, Learning rate: 0.100000
# Train Epoch: 10 [10500/50000 (21%)]	Loss: 4.454062, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [12000/50000 (24%)]	Loss: 4.050558, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [13500/50000 (27%)]	Loss: 4.499273, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [15000/50000 (30%)]	Loss: 4.255882, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [16500/50000 (33%)]	Loss: 4.383446, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [18000/50000 (36%)]	Loss: 4.475564, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [19500/50000 (39%)]	Loss: 4.062682, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [21000/50000 (42%)]	Loss: 4.418138, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [22500/50000 (45%)]	Loss: 4.395535, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [24000/50000 (48%)]	Loss: 4.405476, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [25500/50000 (51%)]	Loss: 4.601288, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [27000/50000 (54%)]	Loss: 4.452294, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [28500/50000 (57%)]	Loss: 4.590544, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [30000/50000 (60%)]	Loss: 4.037291, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [31500/50000 (63%)]	Loss: 4.153852, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [33000/50000 (66%)]	Loss: 4.307905, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [34500/50000 (69%)]	Loss: 4.628216, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [36000/50000 (72%)]	Loss: 4.515043, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [37500/50000 (75%)]	Loss: 4.151769, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [39000/50000 (78%)]	Loss: 4.313318, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [40500/50000 (81%)]	Loss: 4.285501, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [42000/50000 (84%)]	Loss: 4.282172, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [43500/50000 (87%)]	Loss: 4.365985, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [45000/50000 (90%)]	Loss: 4.017678, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [46500/50000 (93%)]	Loss: 4.343641, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [48000/50000 (96%)]	Loss: 4.571265, Accuracy: 77%, Learning rate: 0.100000
# Train Epoch: 10 [49500/50000 (99%)]	Loss: 4.156991, Accuracy: 77%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0133, Accuracy: 5361/10000 (54%)
#
# SSL with 4000 labeled samples, epoch 11
# Train Epoch: 11 [1500/50000 (3%)]	Loss: 4.205468, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [3000/50000 (6%)]	Loss: 4.419119, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [4500/50000 (9%)]	Loss: 4.160949, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [6000/50000 (12%)]	Loss: 4.341474, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [7500/50000 (15%)]	Loss: 4.490022, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [9000/50000 (18%)]	Loss: 4.472223, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [10500/50000 (21%)]	Loss: 3.942166, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [12000/50000 (24%)]	Loss: 4.201863, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [13500/50000 (27%)]	Loss: 4.263556, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [15000/50000 (30%)]	Loss: 4.283668, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [16500/50000 (33%)]	Loss: 4.539235, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [18000/50000 (36%)]	Loss: 4.289815, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [19500/50000 (39%)]	Loss: 4.248357, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [21000/50000 (42%)]	Loss: 4.088982, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [22500/50000 (45%)]	Loss: 4.326979, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [24000/50000 (48%)]	Loss: 4.352823, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [25500/50000 (51%)]	Loss: 4.544739, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [27000/50000 (54%)]	Loss: 4.314039, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [28500/50000 (57%)]	Loss: 4.141629, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [30000/50000 (60%)]	Loss: 3.967860, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [31500/50000 (63%)]	Loss: 4.200474, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [33000/50000 (66%)]	Loss: 4.476589, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [34500/50000 (69%)]	Loss: 4.363241, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [36000/50000 (72%)]	Loss: 3.804824, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [37500/50000 (75%)]	Loss: 4.389595, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [39000/50000 (78%)]	Loss: 4.265141, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [40500/50000 (81%)]	Loss: 4.207351, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [42000/50000 (84%)]	Loss: 4.511631, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [43500/50000 (87%)]	Loss: 4.324116, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [45000/50000 (90%)]	Loss: 4.315440, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [46500/50000 (93%)]	Loss: 3.895594, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [48000/50000 (96%)]	Loss: 4.389187, Accuracy: 78%, Learning rate: 0.100000
# Train Epoch: 11 [49500/50000 (99%)]	Loss: 4.017548, Accuracy: 78%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0131, Accuracy: 5453/10000 (55%)
#
# SSL with 4000 labeled samples, epoch 12
# Train Epoch: 12 [1500/50000 (3%)]	Loss: 4.034617, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 12 [3000/50000 (6%)]	Loss: 3.818627, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [4500/50000 (9%)]	Loss: 3.770933, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [6000/50000 (12%)]	Loss: 4.062401, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [7500/50000 (15%)]	Loss: 4.404262, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [9000/50000 (18%)]	Loss: 4.197827, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [10500/50000 (21%)]	Loss: 4.286242, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [12000/50000 (24%)]	Loss: 4.349357, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [13500/50000 (27%)]	Loss: 3.853869, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [15000/50000 (30%)]	Loss: 4.375893, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [16500/50000 (33%)]	Loss: 4.423011, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [18000/50000 (36%)]	Loss: 4.266763, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [19500/50000 (39%)]	Loss: 4.373048, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [21000/50000 (42%)]	Loss: 4.422854, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [22500/50000 (45%)]	Loss: 4.293659, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [24000/50000 (48%)]	Loss: 4.284155, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [25500/50000 (51%)]	Loss: 4.176602, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [27000/50000 (54%)]	Loss: 4.288362, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [28500/50000 (57%)]	Loss: 3.691168, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [30000/50000 (60%)]	Loss: 4.319445, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [31500/50000 (63%)]	Loss: 3.860575, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [33000/50000 (66%)]	Loss: 3.887480, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [34500/50000 (69%)]	Loss: 3.861382, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [36000/50000 (72%)]	Loss: 4.389484, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [37500/50000 (75%)]	Loss: 4.347726, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [39000/50000 (78%)]	Loss: 4.282003, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [40500/50000 (81%)]	Loss: 3.843696, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [42000/50000 (84%)]	Loss: 3.989063, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [43500/50000 (87%)]	Loss: 3.692103, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [45000/50000 (90%)]	Loss: 3.951284, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [46500/50000 (93%)]	Loss: 4.292792, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [48000/50000 (96%)]	Loss: 4.444411, Accuracy: 79%, Learning rate: 0.100000
# Train Epoch: 12 [49500/50000 (99%)]	Loss: 4.401349, Accuracy: 79%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0127, Accuracy: 5579/10000 (56%)
#
# SSL with 4000 labeled samples, epoch 13
# Train Epoch: 13 [1500/50000 (3%)]	Loss: 4.332808, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [3000/50000 (6%)]	Loss: 4.165516, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [4500/50000 (9%)]	Loss: 4.290470, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [6000/50000 (12%)]	Loss: 3.989126, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [7500/50000 (15%)]	Loss: 4.084078, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [9000/50000 (18%)]	Loss: 4.053503, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [10500/50000 (21%)]	Loss: 4.280919, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [12000/50000 (24%)]	Loss: 3.763963, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [13500/50000 (27%)]	Loss: 4.109639, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [15000/50000 (30%)]	Loss: 4.011793, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [16500/50000 (33%)]	Loss: 4.008520, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [18000/50000 (36%)]	Loss: 3.608718, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [19500/50000 (39%)]	Loss: 4.104176, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [21000/50000 (42%)]	Loss: 3.738756, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [22500/50000 (45%)]	Loss: 3.752734, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [24000/50000 (48%)]	Loss: 3.846058, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [25500/50000 (51%)]	Loss: 3.798910, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [27000/50000 (54%)]	Loss: 3.953634, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [28500/50000 (57%)]	Loss: 4.306304, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [30000/50000 (60%)]	Loss: 4.380999, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [31500/50000 (63%)]	Loss: 4.066428, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [33000/50000 (66%)]	Loss: 4.329084, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [34500/50000 (69%)]	Loss: 4.298546, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [36000/50000 (72%)]	Loss: 4.269710, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [37500/50000 (75%)]	Loss: 4.096153, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [39000/50000 (78%)]	Loss: 3.780659, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [40500/50000 (81%)]	Loss: 4.354610, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [42000/50000 (84%)]	Loss: 4.373644, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [43500/50000 (87%)]	Loss: 4.398333, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [45000/50000 (90%)]	Loss: 4.006390, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [46500/50000 (93%)]	Loss: 3.947995, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [48000/50000 (96%)]	Loss: 4.372175, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 13 [49500/50000 (99%)]	Loss: 4.047330, Accuracy: 80%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0126, Accuracy: 5669/10000 (57%)
#
# SSL with 4000 labeled samples, epoch 14
# Train Epoch: 14 [1500/50000 (3%)]	Loss: 4.111194, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 14 [3000/50000 (6%)]	Loss: 4.197342, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [4500/50000 (9%)]	Loss: 3.696115, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [6000/50000 (12%)]	Loss: 4.163835, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [7500/50000 (15%)]	Loss: 3.736368, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [9000/50000 (18%)]	Loss: 4.287145, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [10500/50000 (21%)]	Loss: 3.707825, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [12000/50000 (24%)]	Loss: 4.272678, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [13500/50000 (27%)]	Loss: 4.254225, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [15000/50000 (30%)]	Loss: 3.938162, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [16500/50000 (33%)]	Loss: 4.252378, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [18000/50000 (36%)]	Loss: 3.895348, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [19500/50000 (39%)]	Loss: 4.164059, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [21000/50000 (42%)]	Loss: 3.880346, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [22500/50000 (45%)]	Loss: 3.891363, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [24000/50000 (48%)]	Loss: 4.132811, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [25500/50000 (51%)]	Loss: 3.638255, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [27000/50000 (54%)]	Loss: 4.275387, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [28500/50000 (57%)]	Loss: 3.793147, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [30000/50000 (60%)]	Loss: 3.584414, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [31500/50000 (63%)]	Loss: 3.645332, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [33000/50000 (66%)]	Loss: 4.249463, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [34500/50000 (69%)]	Loss: 4.276536, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [36000/50000 (72%)]	Loss: 4.221193, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [37500/50000 (75%)]	Loss: 3.954005, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [39000/50000 (78%)]	Loss: 3.627722, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [40500/50000 (81%)]	Loss: 3.765847, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [42000/50000 (84%)]	Loss: 3.486837, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [43500/50000 (87%)]	Loss: 4.033133, Accuracy: 80%, Learning rate: 0.100000
# Train Epoch: 14 [45000/50000 (90%)]	Loss: 4.010986, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 14 [46500/50000 (93%)]	Loss: 4.053174, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 14 [48000/50000 (96%)]	Loss: 4.300433, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 14 [49500/50000 (99%)]	Loss: 4.066721, Accuracy: 81%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0123, Accuracy: 5857/10000 (59%)
#
# SSL with 4000 labeled samples, epoch 15
# Train Epoch: 15 [1500/50000 (3%)]	Loss: 3.971657, Accuracy: 82%, Learning rate: 0.100000
# Train Epoch: 15 [3000/50000 (6%)]	Loss: 4.108170, Accuracy: 82%, Learning rate: 0.100000
# Train Epoch: 15 [4500/50000 (9%)]	Loss: 4.253079, Accuracy: 82%, Learning rate: 0.100000
# Train Epoch: 15 [6000/50000 (12%)]	Loss: 4.090789, Accuracy: 82%, Learning rate: 0.100000
# Train Epoch: 15 [7500/50000 (15%)]	Loss: 4.082444, Accuracy: 82%, Learning rate: 0.100000
# Train Epoch: 15 [9000/50000 (18%)]	Loss: 4.312078, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [10500/50000 (21%)]	Loss: 4.061514, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [12000/50000 (24%)]	Loss: 4.297152, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [13500/50000 (27%)]	Loss: 4.012797, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [15000/50000 (30%)]	Loss: 3.691778, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [16500/50000 (33%)]	Loss: 3.778401, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [18000/50000 (36%)]	Loss: 3.571465, Accuracy: 82%, Learning rate: 0.100000
# Train Epoch: 15 [19500/50000 (39%)]	Loss: 4.215442, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [21000/50000 (42%)]	Loss: 4.100574, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [22500/50000 (45%)]	Loss: 4.175550, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [24000/50000 (48%)]	Loss: 4.027871, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [25500/50000 (51%)]	Loss: 4.026289, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [27000/50000 (54%)]	Loss: 3.428181, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [28500/50000 (57%)]	Loss: 3.883117, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [30000/50000 (60%)]	Loss: 3.880035, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [31500/50000 (63%)]	Loss: 3.969842, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [33000/50000 (66%)]	Loss: 3.811251, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [34500/50000 (69%)]	Loss: 3.984487, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [36000/50000 (72%)]	Loss: 3.984491, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [37500/50000 (75%)]	Loss: 4.314174, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [39000/50000 (78%)]	Loss: 4.269728, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [40500/50000 (81%)]	Loss: 4.012937, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [42000/50000 (84%)]	Loss: 4.173035, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [43500/50000 (87%)]	Loss: 4.198696, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [45000/50000 (90%)]	Loss: 4.129706, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [46500/50000 (93%)]	Loss: 4.271434, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [48000/50000 (96%)]	Loss: 4.170724, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 15 [49500/50000 (99%)]	Loss: 4.016795, Accuracy: 81%, Learning rate: 0.100000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0121, Accuracy: 5931/10000 (59%)
#
# SSL with 4000 labeled samples, epoch 16
# Train Epoch: 16 [1500/50000 (3%)]	Loss: 3.654097, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 16 [3000/50000 (6%)]	Loss: 4.063360, Accuracy: 81%, Learning rate: 0.100000
# Train Epoch: 16 [4500/50000 (9%)]	Loss: 3.917807, Accuracy: 82%, Learning rate: 0.100000
# Train Epoch: 16 [6000/50000 (12%)]	Loss: 4.077933, Accuracy: 81%, Learning rate: 0.100000
# ...
# Train Epoch: 95 [49500/50000 (99%)]	Loss: 3.750914, Accuracy: 95%, Learning rate: 0.001000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0043, Accuracy: 8685/10000 (87%)
#
# SSL with 4000 labeled samples, epoch 96
# Train Epoch: 96 [1500/50000 (3%)]	Loss: 3.462512, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [3000/50000 (6%)]	Loss: 3.200152, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [4500/50000 (9%)]	Loss: 3.276553, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [6000/50000 (12%)]	Loss: 3.515429, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [7500/50000 (15%)]	Loss: 2.759555, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [9000/50000 (18%)]	Loss: 3.568269, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [10500/50000 (21%)]	Loss: 2.886211, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [12000/50000 (24%)]	Loss: 2.900947, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [13500/50000 (27%)]	Loss: 3.446273, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [15000/50000 (30%)]	Loss: 2.917347, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [16500/50000 (33%)]	Loss: 2.936135, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [18000/50000 (36%)]	Loss: 3.678468, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [19500/50000 (39%)]	Loss: 3.613858, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [21000/50000 (42%)]	Loss: 3.468158, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [22500/50000 (45%)]	Loss: 2.524257, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [24000/50000 (48%)]	Loss: 3.459255, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [25500/50000 (51%)]	Loss: 3.314753, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [27000/50000 (54%)]	Loss: 3.512809, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [28500/50000 (57%)]	Loss: 3.648888, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [30000/50000 (60%)]	Loss: 3.119497, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [31500/50000 (63%)]	Loss: 3.633125, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [33000/50000 (66%)]	Loss: 3.565547, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [34500/50000 (69%)]	Loss: 3.590892, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [36000/50000 (72%)]	Loss: 3.331675, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [37500/50000 (75%)]	Loss: 3.548128, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [39000/50000 (78%)]	Loss: 3.148946, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [40500/50000 (81%)]	Loss: 2.669903, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [42000/50000 (84%)]	Loss: 3.637963, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [43500/50000 (87%)]	Loss: 2.709337, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [45000/50000 (90%)]	Loss: 3.482277, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [46500/50000 (93%)]	Loss: 3.739937, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [48000/50000 (96%)]	Loss: 2.976336, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 96 [49500/50000 (99%)]	Loss: 3.635741, Accuracy: 95%, Learning rate: 0.001000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0043, Accuracy: 8668/10000 (87%)
#
# SSL with 4000 labeled samples, epoch 97
# Train Epoch: 97 [1500/50000 (3%)]	Loss: 3.413880, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 97 [3000/50000 (6%)]	Loss: 2.692115, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [4500/50000 (9%)]	Loss: 3.033275, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [6000/50000 (12%)]	Loss: 3.077253, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [7500/50000 (15%)]	Loss: 3.384462, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [9000/50000 (18%)]	Loss: 3.171604, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [10500/50000 (21%)]	Loss: 3.380907, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [12000/50000 (24%)]	Loss: 3.670182, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [13500/50000 (27%)]	Loss: 2.644247, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [15000/50000 (30%)]	Loss: 2.416202, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [16500/50000 (33%)]	Loss: 3.449299, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [18000/50000 (36%)]	Loss: 2.844673, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [19500/50000 (39%)]	Loss: 3.081701, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [21000/50000 (42%)]	Loss: 3.533106, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [22500/50000 (45%)]	Loss: 2.769454, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [24000/50000 (48%)]	Loss: 2.934380, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [25500/50000 (51%)]	Loss: 2.871367, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [27000/50000 (54%)]	Loss: 2.451197, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [28500/50000 (57%)]	Loss: 3.573432, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [30000/50000 (60%)]	Loss: 2.937423, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [31500/50000 (63%)]	Loss: 2.741893, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [33000/50000 (66%)]	Loss: 3.036942, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [34500/50000 (69%)]	Loss: 3.151517, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [36000/50000 (72%)]	Loss: 3.204365, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [37500/50000 (75%)]	Loss: 2.441511, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [39000/50000 (78%)]	Loss: 3.102700, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [40500/50000 (81%)]	Loss: 3.579829, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [42000/50000 (84%)]	Loss: 3.343149, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [43500/50000 (87%)]	Loss: 2.771678, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [45000/50000 (90%)]	Loss: 3.399464, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [46500/50000 (93%)]	Loss: 2.871237, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [48000/50000 (96%)]	Loss: 3.389794, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 97 [49500/50000 (99%)]	Loss: 3.419762, Accuracy: 95%, Learning rate: 0.001000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0043, Accuracy: 8685/10000 (87%)
#
# SSL with 4000 labeled samples, epoch 98
# Train Epoch: 98 [1500/50000 (3%)]	Loss: 2.916814, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 98 [3000/50000 (6%)]	Loss: 3.621983, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 98 [4500/50000 (9%)]	Loss: 3.584770, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [6000/50000 (12%)]	Loss: 2.779418, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [7500/50000 (15%)]	Loss: 3.706446, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [9000/50000 (18%)]	Loss: 3.504152, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [10500/50000 (21%)]	Loss: 3.559795, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [12000/50000 (24%)]	Loss: 2.996902, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [13500/50000 (27%)]	Loss: 3.514906, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [15000/50000 (30%)]	Loss: 2.900400, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [16500/50000 (33%)]	Loss: 3.300926, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [18000/50000 (36%)]	Loss: 2.740800, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [19500/50000 (39%)]	Loss: 2.494456, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [21000/50000 (42%)]	Loss: 3.386487, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [22500/50000 (45%)]	Loss: 3.223225, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [24000/50000 (48%)]	Loss: 3.377609, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [25500/50000 (51%)]	Loss: 3.516983, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [27000/50000 (54%)]	Loss: 3.554153, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [28500/50000 (57%)]	Loss: 3.521214, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [30000/50000 (60%)]	Loss: 3.259002, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [31500/50000 (63%)]	Loss: 3.580904, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [33000/50000 (66%)]	Loss: 2.558118, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [34500/50000 (69%)]	Loss: 2.526726, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [36000/50000 (72%)]	Loss: 3.712923, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [37500/50000 (75%)]	Loss: 3.063830, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [39000/50000 (78%)]	Loss: 3.758150, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [40500/50000 (81%)]	Loss: 2.605412, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [42000/50000 (84%)]	Loss: 3.568662, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [43500/50000 (87%)]	Loss: 3.400754, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [45000/50000 (90%)]	Loss: 3.459074, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [46500/50000 (93%)]	Loss: 3.042360, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [48000/50000 (96%)]	Loss: 3.572635, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 98 [49500/50000 (99%)]	Loss: 2.759128, Accuracy: 95%, Learning rate: 0.001000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0043, Accuracy: 8662/10000 (87%)
#
# SSL with 4000 labeled samples, epoch 99
# Train Epoch: 99 [1500/50000 (3%)]	Loss: 2.763270, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [3000/50000 (6%)]	Loss: 3.421111, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [4500/50000 (9%)]	Loss: 3.375056, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [6000/50000 (12%)]	Loss: 2.649052, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [7500/50000 (15%)]	Loss: 2.511304, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [9000/50000 (18%)]	Loss: 3.456183, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [10500/50000 (21%)]	Loss: 2.765642, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [12000/50000 (24%)]	Loss: 3.613402, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [13500/50000 (27%)]	Loss: 3.059036, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [15000/50000 (30%)]	Loss: 2.966263, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [16500/50000 (33%)]	Loss: 3.685150, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [18000/50000 (36%)]	Loss: 3.495098, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [19500/50000 (39%)]	Loss: 3.741556, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [21000/50000 (42%)]	Loss: 2.473725, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [22500/50000 (45%)]	Loss: 2.993537, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [24000/50000 (48%)]	Loss: 3.419376, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [25500/50000 (51%)]	Loss: 3.269714, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [27000/50000 (54%)]	Loss: 3.226974, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [28500/50000 (57%)]	Loss: 3.470912, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [30000/50000 (60%)]	Loss: 3.564390, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [31500/50000 (63%)]	Loss: 3.480368, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [33000/50000 (66%)]	Loss: 3.062601, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [34500/50000 (69%)]	Loss: 3.415902, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [36000/50000 (72%)]	Loss: 3.257740, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [37500/50000 (75%)]	Loss: 3.300702, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [39000/50000 (78%)]	Loss: 3.629516, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [40500/50000 (81%)]	Loss: 3.793600, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [42000/50000 (84%)]	Loss: 2.618728, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [43500/50000 (87%)]	Loss: 3.510990, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [45000/50000 (90%)]	Loss: 3.582800, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [46500/50000 (93%)]	Loss: 3.506582, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [48000/50000 (96%)]	Loss: 3.317369, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 99 [49500/50000 (99%)]	Loss: 3.712307, Accuracy: 95%, Learning rate: 0.001000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0043, Accuracy: 8685/10000 (87%)
#
# SSL with 4000 labeled samples, epoch 100
# Train Epoch: 100 [1500/50000 (3%)]	Loss: 2.790810, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 100 [3000/50000 (6%)]	Loss: 3.420925, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [4500/50000 (9%)]	Loss: 3.638511, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [6000/50000 (12%)]	Loss: 2.845798, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 100 [7500/50000 (15%)]	Loss: 2.735430, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 100 [9000/50000 (18%)]	Loss: 3.333879, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 100 [10500/50000 (21%)]	Loss: 3.015843, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 100 [12000/50000 (24%)]	Loss: 3.364486, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 100 [13500/50000 (27%)]	Loss: 3.045312, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 100 [15000/50000 (30%)]	Loss: 3.730025, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 100 [16500/50000 (33%)]	Loss: 2.686661, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 100 [18000/50000 (36%)]	Loss: 3.568381, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 100 [19500/50000 (39%)]	Loss: 2.425439, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 100 [21000/50000 (42%)]	Loss: 2.505264, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 100 [22500/50000 (45%)]	Loss: 3.725383, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [24000/50000 (48%)]	Loss: 3.054298, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [25500/50000 (51%)]	Loss: 2.771555, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [27000/50000 (54%)]	Loss: 3.442145, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [28500/50000 (57%)]	Loss: 2.681749, Accuracy: 96%, Learning rate: 0.001000
# Train Epoch: 100 [30000/50000 (60%)]	Loss: 3.601643, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [31500/50000 (63%)]	Loss: 3.359128, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [33000/50000 (66%)]	Loss: 3.438239, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [34500/50000 (69%)]	Loss: 2.937283, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [36000/50000 (72%)]	Loss: 3.520157, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [37500/50000 (75%)]	Loss: 2.697857, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [39000/50000 (78%)]	Loss: 3.556521, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [40500/50000 (81%)]	Loss: 3.469836, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [42000/50000 (84%)]	Loss: 3.029024, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [43500/50000 (87%)]	Loss: 2.865230, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [45000/50000 (90%)]	Loss: 3.215750, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [46500/50000 (93%)]	Loss: 2.989347, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [48000/50000 (96%)]	Loss: 3.293416, Accuracy: 95%, Learning rate: 0.001000
# Train Epoch: 100 [49500/50000 (99%)]	Loss: 3.042889, Accuracy: 95%, Learning rate: 0.001000
# Samples relabeled with the prediction:  46000
#
# Test set: Average loss: 0.0043, Accuracy: 8667/10000 (87%)

# %% [markdown]
# # Accuracy and loss curves

# %%
##Accuracy
acc_train = np.load(res_path + '/' + 'accuracy_per_epoch_train.npy')
acc_test = np.load(res_path + '/' + 'accuracy_per_epoch_val.npy')

#Loss per epoch
loss_train = np.load(res_path + '/' + 'LOSS_epoch_train.npy')
loss_test = np.load(res_path + '/' + 'LOSS_epoch_val.npy')

numEpochs = len(acc_train)
epochs = range(numEpochs)

plt.figure(1)
plt.plot(epochs, acc_test, label='Test, max acc: ' + str(np.max(acc_test)))
plt.plot(epochs, acc_train, label='Train, max acc: ' + str(np.max(acc_train)))
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

plt.figure(2)
plt.plot(epochs, loss_test, label='Test, min loss: ' + str(np.min(loss_test)))
plt.plot(epochs, loss_train, label='Train, min loss: ' + str(np.min(loss_train)))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

plt.show()
